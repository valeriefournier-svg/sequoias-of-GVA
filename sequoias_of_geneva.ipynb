# %%
import pandas as pd
df = pd.read_csv("sequoiaGE.csv", sep=';', low_memory=False)

# %%
df.shape
# Out:
# (238789, 23)

# %%
df.head()
# Out:
#    OBJECTID  ID_NOM  ID_TAXON  ID_ARBRE     CLASSE NOM_LATIN NOM_COM_GE  \
# 0       114   10481     24954    172763  Conifères     Pinus        Pin
# 1       115   10837     26178    137146   Feuillus   Populus   Peuplier
# 2       116   10481     24954    137147  Conifères     Pinus        Pin
# 3       117   14788     38896    138208  Conifères     Taxus         If
# 4       118   10481     24954    138212  Conifères     Pinus        Pin
#
#   NOM_COMMUN NOM_COM_RE  DIAM_1M  ...  CHAMPION  INT_PHENO      STATUT  \
# 0        Pin        Pin      NaN  ...         0        NaN  Historique
# 1   Peuplier   Peuplier      NaN  ...         0        NaN  Historique
# 2        Pin        Pin      NaN  ...         0        NaN  Historique
# 3         If         If      NaN  ...         0        NaN  Historique
# 4        Pin        Pin      NaN  ...         0        NaN  Historique
#
#                                              ADR_URL            COMMUNE  \
# ...

# %%
sequoia = df[df['NOM_COMMUN'] == 'Séquoia']

# %%
sequoia
# Out:
#         OBJECTID  ID_NOM  ID_TAXON  ID_ARBRE     CLASSE         NOM_LATIN  \
# 250          168   13998     37435    132408  Conifères    Sequoiadendron
# 1560        1480   13998     37435      1540  Conifères    Sequoiadendron
# 1653        1598   13998     37435      3359  Conifères    Sequoiadendron
# 1743        1688   13998     37435      2508  Conifères    Sequoiadendron
# 1746        1691   13998     37435      2511  Conifères    Sequoiadendron
# ...          ...     ...       ...       ...        ...               ...
# 192677    191168   13993     37420    303376  Conifères           Sequoia
# 192678    191169   13993     37420    303377  Conifères           Sequoia
# 195251    193335   13993     37420    303536  Conifères           Sequoia
# 217296    217879   13998     37435    351062  Conifères    Sequoiadendron
# 231520    232580   13994     37421    388714  Conifères  Sequoia gigantea
#
#        NOM_COM_GE NOM_COMMUN                       NOM_COM_RE  DIAM_1M  ...  \
# ...

# %%
sequoia.shape
# Out:
# (259, 23)

# %%
sequoia.to_csv('sequoia_list.csv', index=False)
